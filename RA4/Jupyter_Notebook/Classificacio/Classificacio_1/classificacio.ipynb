# %% [markdown]
# ## IMPORTS ##

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %% [markdown]
# ### CARREGA DE DADES ###

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data',
 names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang',
'oldpeak', 'slope', 'ca', 'thal', 'num'],
 na_values='?'
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heartdisease/processed.cleveland.data',
#       2  names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang',
#       3 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       4  na_values='?'
#       5 )
#
# ...

# %% [markdown]
# ### PREPROCESSAMENT DE DADES ###

# %%
# Eliminar filas con valores nulos
df.dropna(inplace=True)
# Convertir a problema de clasificación binaria. Atributo target es num, y se distinguen dos casos:
# num=0 (negativo) y num=1 (positivo)
for ind, row in df.iterrows():
    if row['num'] > 0:
        df.at[ind, 'num'] = 1

# %% [markdown]
# ### PREPARACIÓ DE FEATURES I TARGET ###

# %%
# x: eliminar target y atributos categóricos. Utilizar los dicotómicos sex, fbs y exang como atributos predictores.
x = df.drop(['num', 'cp', 'restecg', 'slope', 'thal'], axis=1)
# y: target
y = df['num']

# %% [markdown]
# ### NORMALITZACIÓ ###

# %%
# Normalización de atributos predictores (x)
x = (x-np.min(x))/(np.max(x)-np.min(x))

# %% [markdown]
# ### DIVISIÓ TRAIN-TEST ###

# %%
RANDOM_SEED = 42
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=RANDOM_SEED)

# %% [markdown]
# ### ENTRENAMENT DEL MODEL ###

# %%
# Entrenamiento de un clasificador k-NN
k = 11
clf = KNeighborsClassifier(n_neighbors = k)
clf.fit(x_train, y_train)

# %% [markdown]
# ### PREDICCIÓ ###

# %%
# Validación
y_pred = clf.predict(x_test)

# %% [markdown]
# ### FUNCIÓ AUXILIAR: MATRIU DE CONFUSIÓ ###

# %%
def plot_confusion_matrix(y_true, y_pred, normalize=None,
                          title=None, cmap=plt.cm.Blues, rotation=0):

    (...)

# %% [markdown]
# ### VISUALITZACIÓ MATRIU DE CONFUSIÓ ###

# %%
plot_confusion_matrix(y_test, y_pred, cmap='YlGn', rotation=0)

# %% [markdown]
# ### MÈTRIQUES DEL MODEL ###

# %%
acc_rate = accuracy_score(y_test, y_pred)
print("Tasa de acierto en dataset de validación: ", acc_rate)
y_pred = clf.predict(x_train)
acc_rate = accuracy_score(y_train, y_pred)

# %% [markdown]
# ### MÈTRIQUES DETALLADES ###

# %%
print("Tasa de acierto en dataset de entrenamiento: ", acc_rate)
y_pred = clf.predict(x_test)
print("precisión: ", precision_score(y_test, y_pred))
print("sensibilidad (recall): ", recall_score(y_test, y_pred))
print("f1-score: ", f1_score(y_test, y_pred))
print("Métricas para dataset de validación: \n"
 +classification_report(y_test, y_pred))

# %% [markdown]
# ### DETALLS MATRIU DE CONFUSIÓ ###

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
print('TP: ', cm[1][1])
print('TN: ', cm[0][0])
print('FP: ', cm[0][1])
print('FN: ', cm[1][0])
